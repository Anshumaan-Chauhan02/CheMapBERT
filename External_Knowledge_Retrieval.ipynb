# %%
import requests
from bs4 import BeautifulSoup

# List of ingredients to search for
ingredient_list = ["Water", "Glycerin","Saccharide Isomerate"]
for i in range(len(ingredient_list)):
  new_name = ""
  if len(ingredient_list[i].split())>1:
    for j in ingredient_list[i].split():
      if new_name=="":
        new_name=j
      else:
        new_name=new_name+"+"+j
  if new_name!="":
    ingredient_list[i]=new_name
    new_name=""
    
# URL to search for products
url = f"https://incidecoder.com/search/product?query=&include={'&include='.join(ingredient_list)}"

#URL to which a GET request is sent
print(url)

# Retrieve the webpage content
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find all the product names on the webpage
product_names = []
for result in soup.find_all("a", class_="klavika simpletextlistitem"):
    name = result.text.strip()
    product_names.append(name)

# Print the list of product names
print(product_names)
# Out:
# https://incidecoder.com/search/product?query=&include=Water&include=Glycerin&include=Saccharide+Isomerate
# ['cnk Christine Niklas AA Creme - Anti Redness', 'Charlotte Tilbury Magic Eye Rescue Cream', 'Code of Harmony Chill Gel Masque - Cbd Face Mask', 'NYDG Ultra-Light Hydra-Gel', 'Tata Harper Elixir Vitae Eye Serum', 'Janssen Cosmetics Skin Contour Cream', 'Dermasence RosaMin Serum', 'Susanne Kaufmann Nutrient Concentrate Skin Smoothing', 'Eisenberg Youth Elixir Illuminating Lifting Gel', 'Dr. van der Hoog Hypoallergen Anti-Aging Day Cream', 'Philosophy Renewed Hope In A Jar Peeling Face Mask', 'Tata Harper Hydrating Floral Essence', 'DerMend Alpha + Beta Hydroxy Therapy', "Trader Joe's Ultra Hydrating Gel Moisturizer", 'Miss Spa Rose Stem Cell Sheet Mask', 'Equate Scalp Care Super Shampoo - Green Tea + Apple', 'La Mer The Reparative Body Lotion', 'StriVectin Supergreens Soother™ Cooling Gel Mask', 'Derma Elravie Moist Hyal Power Ampoule', 'Clarks Botanicals Deep Moisture Mask', 'SkinBetter Hydration Boosting Cream', 'Cosmedix Phytoclear Clarifying Moisturizer', 'Chantecaille Stress Repair Concentrate+', 'Kruidvat Skin Science Skin Science Anti-Age Cell Renewal Night Cream', 'Miami Beach Bum The Facial In A Jar', 'Snowberry So Soft Cleanser', 'Lumene Arctic Hydra Care [Arktis] Moisture & Relief Rich Eye Cream', 'Dr Dennis Gross Ferulic + Retinol Fortifying Neck Emulsion', 'Kristina Holey + Marie Veronique Barrier Restore Serum', 'Bad Habit Daily Dose Multivitamin Moisturizer', 'Lumene Lähde Intense Hydration 24H', 'Dr. G Aquasis Moisture Toner', 'Goodal Ampoule Mist Witch Hazel', 'Elw Ansiktscreme Anti-Age', 'Biobelle #Staygorgeous Facial Mask', 'Lumene Arctic Hydra Care Moisture & Relief Rich Oleo-Serum', 'Air Repair Protect + Prevent Hydrating Serum', 'Eisenberg Active Mattifying Secret', 'Vision Face Fluid Spf 30', 'Valmont V-Line Lifting Concentrate', 'M Picaut Hydra Lagoon Overnight Mask', 'Dermalogica Age Bright Spot Fader', 'MEDICARE  Hydrant Day', 'mezolux by LIBREDERM Lightening Booster', 'Derma Essentia Gentle Cleansing Lotion', 'Glossier Zit Stick', 'Dr Dennis Gross Hyaluronic Marine Meltaway Cleanser', 'ORIENTANA Bio Essence-Mask Philippine Seaweed', 'Tria Age-Defying Skincare Overnight Brightening Boost Facial', 'KIKO Milano Sebo Balance Cream']
